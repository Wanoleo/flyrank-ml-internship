# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Wanoleo/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My Lane
#
# I selected the Content Refresh Prioritization lane because it focuses on identifying webpages that are most likely to decline in search performance. Content teams usually have many pages to manage, so prioritizing which pages to refresh first can help them use their time more effectively. This problem is suitable for machine learning because multiple page characteristics can be analyzed together to support better decisions.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ##2. The Question
#
# **Decision:** Which webpages should be prioritized for content refresh?
#
# **Action:** Content editors review and update the pages ranked highest by the model.
#
# **Unit of analysis:** One webpage.
#
# **Output:** A ranked list of pages most likely to require a content refresh.
#
# **Cost of a wrong recommendation:** False positives waste editorial time by recommending pages that do not need updates. False negatives may cause declining pages to be ignored, potentially leading to continued traffic loss.
#
# **Why ML helps:** Machine learning can combine several page features to identify patterns that are difficult to capture using simple manual rules.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Rows:", df.shape[0])
print("Columns:", df.shape[1])

print("\nTrend Direction Counts:")
print(df["trend_direction"].value_counts())

print("\nMedian Word Count:", df["word_count"].median())

# %% [markdown]
# ##4. What I Can and Cannot Claim
#
# This project provides decision support based on patterns observed in the anonymized dataset. The findings describe relationships measured in the data and can help prioritize content for review.
#
# The results should not be interpreted as proof of how search engines rank pages or as a guarantee that updating a page will improve its performance.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
