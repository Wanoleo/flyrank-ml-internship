# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Wanoleo/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# My chosen lane is a classification problem.
#
# The goal is to classify whether a content page is likely to be declining based on its observable performance metrics. The prediction helps content editors identify which pages should be reviewed first. Classification is appropriate because the output is a binary decision: declining or not declining.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# The target is **is_declining_label**, which identifies whether a content page is declining.
#
# This label is derived from the observed trend direction in the starter dataset. It is used as a proxy for deciding whether a page should be considered for content refresh.
#
# The target represents an observed outcome rather than a manually assigned priority score.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# The primary success metric is Precision@50.
#
# This metric measures how many of the top 50 pages recommended by the model are actually declining. It is appropriate because editors usually review only a limited number of pages, so recommending the most useful pages first is more valuable than maximizing overall accuracy.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
# One row represents one content page.
#
# Each row contains information about a single page, including impressions, click-through rate (CTR), average search position, content age, engagement metrics, and trend information.

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# Create the target label
df["is_declining_label"] = (
    df["trend_direction"]
      .str.lower()
      .eq("down")
      .astype(int)
)

print("Dataset shape:", df.shape)
print("\nEach row represents one content page.\n")

df[[
    "content_id",
    "client_id",
    "content_type",
    "impressions_90d",
    "ctr",
    "avg_position",
    "trend_direction",
    "is_declining_label"
]].head()
# Out:
# Dataset shape: (30000, 45)
#
# Each row represents one content page.
#              content_id          client_id     content_type  impressions_90d  \
# 0  content_304f48230142  client_f369cb89fc  keyword article             3803
# 1  content_a1fb4e703a9e  client_4e07408562  keyword article            15320
# 2  content_9aa793d4d895  client_7f2253d7e2  keyword article            12581
# 3  content_331d6c4de07b  client_19581e27de  keyword article            11751
# 4  content_d99b7a2d90ca  client_3fdba35f04  keyword article            19140
#
#     ctr  avg_position trend_direction  is_declining_label
# 0  0.76          10.6            down                   1
# 1  0.05          20.3            down                   1
# 2  0.09          36.5            down                   1
# 3  0.49           6.2          stable                   0
# 4  0.13          44.0            down                   1

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# A simple rule, such as selecting pages with the highest impressions or the oldest update date, cannot capture the complex relationships between multiple factors.
#
# Machine learning can combine several observable signals, including impressions, click-through rate, average position, engagement, content age, and update history, to identify declining pages more effectively.
#
# The model provides decision support by producing a ranked list of pages for review, helping editors prioritize their work more efficiently.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
